# %% [markdown]
# <a href="https://colab.research.google.com/github/rashmibenni292-benni/linear-regression-from-scratch/blob/main/linear_regression_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
